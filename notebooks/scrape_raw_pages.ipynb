# %%
import re

from IPython.display import display

import pandas as pd
from pandas import DataFrame as DF, Series

import numpy as np

import requests
from bs4 import BeautifulSoup

# %%
def split_primary_parties(pre):
    parties = {}
    for i,l in enumerate(pre):
        if re.search(r'\*\s\(', l):
            party = [
                s.strip().strip('()') for s in l.split('*') if s
            ][0]
            parties[i] = party
    return parties

def get_html(url):
    r = requests.get(url.replace('\n', ''))
    return r.content.decode('utf-8')

def extract_pre(html):
    soup = BeautifulSoup(html, 'html.parser')
    pre = soup.find('pre')
    pre = pre.contents[0].split('\n')
    return [l.strip() for l in pre]

def extract_row(s):
    s = re.sub(r'\s+(\.\s+)+', '|', s)
    s = re.sub(r'\s{2,}', ' ', s)
    toks = s.split('|')
    return [toks[0], toks[1].split()[0]]

def scrape_rawpage(url, primary=False):
    html = get_html(url)
    pre = extract_pre(html)
    
    all_tables = {}
    parties = False
    if primary:
        parties = split_primary_parties(pre)
    party = None
    
    tables = {}
    title = None
    current_title = None
    parse = False
    for i,l in enumerate(pre):
        if l.startswith('VOTER TURNOUT'):
            parse = True
            continue
        if parties:
            if i in parties:
                if party:
                    all_tables[party] = tables
                party = parties[i]
                continue
        if not parse:
            continue
        if (l == '') or (re.search(r'Vote For\s+\d', l)):
            continue
        if not re.search(r'(\.\s{2})+', l):
            if title:
                title = ' '.join([title, l])
            else:
                title = l
        else:
            if title:
                current_title = title
            title = None
            tables.setdefault(current_title, [])
            # get row values
    #         print(l)
            row = extract_row(l)
            tables[current_title].append(row)
    if primary:
        return all_tables
    return tables

# %% [markdown]
# ## Scrape All Pages

# %%
baseurl = 'https://multco.us/elections/'
urls = [
    'Gnovember-2012-general-election-election-results',
    'Pmay-15-2012-primary-election-election-results',
    'Gnovember-2-2010-election-results',
    'Pmay-18-2010-election-results',
    'Smay-19-2009-election-results',  # special election
    'Gnovember-4-2008-election-results',
    'Pmay-20-2008-election-results',
    'Gnovember-7-2006-election-results',
    'Pmay-16-2006-election-results',
    'Gnovember-2-2004-election-results',
    'Pmay-18-2004-election-results',
]

# %%
all_tables = {}
for u in urls:
    if u.startswith('P'):
        primary = True
    else:
        primary = False
    url = baseurl + u[1:]
    tables = scrape_rawpage(url, primary)
    year = re.search(r'20(0\d|1[0-8]{1})', u).group()
    key = u[0] + year
    all_tables[key] = tables

# %%
list(all_tables)
# Out:
# ['P2004',
#  'P2006',
#  'S2009',
#  'P2012',
#  'G2006',
#  'G2008',
#  'P2008',
#  'G2012',
#  'G2004',
#  'G2010',
#  'P2010']

# %%
all_tables['P2012']
# Out:
# {'Democrat': {'26-125 MULTNOMAH COUNTY LIBRARY': [['Yes', '128,814'],
#    ['No.', '23,566'],
#    ['Over Votes', '22'],
#    ['Under Votes', '8,424']],
#   '26-126 CITY OF PORTLAND': [['Yes', '95,904'],
#    ['No.', '15,356'],
#    ['Over Votes', '36'],
#    ['Under Votes', '28,712']],
#   '26-127 CITY OF PORTLAND': [['Yes', '87,732'],
#    ['No.', '25,581'],
#    ['Over Votes', '32'],
#    ['Under Votes', '26,663']],
#   '26-128 CITY OF PORTLAND': [['Yes', '94,824'],
#    ['No.', '20,739'],
#    ['Over Votes', '23'],
#    ['Under Votes', '24,422']],
#   '26-129 CITY OF PORTLAND': [['Yes', '95,642'],
#    ['No.', '21,823'],
#    ['Over Votes', '30'],
#    ['Under Votes', '22,513']],
#   '26-130 CITY OF PORTLAND': [['Yes', '92,564'],
#    ['No.', '24,894'],
#    ['Over Votes', '23'],
#    ['Under Votes', '22,527']],
#   '26-131 CITY OF PORTLAND': [['Yes', '87,341'],
#    ['No.', '26,517'],
#    ['Over Votes', '36'],
#    ['Under Votes', '26,114']],
#   '26-132 CITY OF PORTLAND': [['Yes', '100,276'],
#    ['No.', '11,454'],
#    ['Over Votes', '18'],
#    ['Under Votes', '28,260']],
#   '26-133 CITY OF PORTLAND': [['Yes', '92,087'],
#    ['No.', '16,066'],
#    ['Over Votes', '28'],
#    ['Under Votes', '31,827']],
#   '26-134 CITY OF PORTLAND': [['Yes', '97,053'],
#    ['No.', '15,047'],
#    ['Over Votes', '19'],
#    ['Under Votes', '27,889']],
#   '26-135 DAVID DOUGLAS SCHOOL DISTRICT #40': [['Yes', '5,680'],
#    ['No.', '3,060'],
#    ['Over Votes', '3'],
#    ['Under Votes', '605']],
#   '26-136 CITY OF GRESHAM': [['Yes', '7,836'],
#    ['No.', '3,077'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,585']],
#   '26-137 CITY OF GRESHAM': [['Yes', '9,054'],
#    ['No.', '1,731'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,713']],
#   '26-138 CITY OF GRESHAM': [['Yes', '9,473'],
#    ['No.', '1,391'],
#    ['Over Votes', '3'],
#    ['Under Votes', '1,631']],
#   '26-139 CITY OF GRESHAM': [['Yes', '9,990'],
#    ['No.', '946'],
#    ['Over Votes', '2'],
#    ['Under Votes', '1,560']],
#   '26-140 CITY OF GRESHAM': [['Yes', '8,696'],
#    ['No.', '1,748'],
#    ['Over Votes', '1'],
#    ['Under Votes', '2,053']],
#   'Attorney General': [['Dwight Holton', '25,889'],
#    ['Ellen Rosenblum', '63,141'],
#    ['WRITE-IN.', '163'],
#    ['Over Votes', '13'],
#    ['Under Votes', '14,029'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '2,452'],
#    ['Over Votes', '0'],
#    ['Under Votes', '27,441']],
#   'Commissioner, Pos. 1 CITY OF PORTLAND': [['Amanda Fritz', '54,323'],
#    ['David G Gwyther', '2,725'],
#    ['Mary Nolan', '52,823'],
#    ['Bruce Altizer', '5,511'],
#    ['Teressa L Raiford.', '3,840'],
#    ['WRITE-IN.', '427'],
#    ['Over Votes', '38'],
#    ['Under Votes', '20,321']],
#   'Commissioner, Pos. 4 CITY OF PORTLAND': [['Scott McAlpine.', '8,851'],
#    ['Brian Sidney Parrott.', '2,341'],
#    ['Steve Novick', '85,536'],
#    ['Mark White', '4,255'],
#    ['Jeri Williams', '5,608'],
#    ['Leah Marie Dumas', '4,879'],
#    ['James Rowell', '1,180'],
#    ['WRITE-IN.', '501'],
#    ['Over Votes', '46'],
#    ['Under Votes', '26,811']],
#   'County Commissioner Dist #1': [['Wes Soderback', '5,449'],
#    ['Deborah Kafoury', '31,954'],
#    ['WRITE-IN.', '183'],
#    ['Over Votes', '18'],
#    ['Under Votes', '15,850']],
#   'County Commissioner Dist #3': [['Judy Shiprack', '18,284'],
#    ['Patty Burkett', '5,835'],
#    ['WRITE-IN.', '238'],
#    ['Over Votes', '9'],
#    ['Under Votes', '12,945']],
#   'County Commissioner Dist #4': [['Diane McKeel', '13,723'],
#    ['WRITE-IN.', '293'],
#    ['Over Votes', '2'],
#    ['Under Votes', '10,693']],
#   'District Attorney, Multnomah County': [['Rod Underhill', '79,555'],
#    ['WRITE-IN.', '1,195'],
#    ['Over Votes', '3'],
#    ['Under Votes', '80,073']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 12': [['Janice R Wilson',
#     '72,187'],
#    ['WRITE-IN.', '966'],
#    ['Over Votes', '4'],
#    ['Under Votes', '87,669']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 16': [['Susan M Svetkey',
#     '72,734'],
#    ['WRITE-IN.', '912'],
#    ['Over Votes', '4'],
#    ['Under Votes', '87,176']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 23': [['Edward Jones', '70,810'],
#    ['WRITE-IN.', '994'],
#    ['Over Votes', '4'],
#    ['Under Votes', '89,018']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 28': [['Judith Hudson Matarazzo.',
#     '71,389'],
#    ['WRITE-IN.', '939'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,494']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 29': [['Kathryn Villa-Smith',
#     '70,773'],
#    ['WRITE-IN.', '925'],
#    ['Over Votes', '3'],
#    ['Under Votes', '89,125']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 3': [['Jerry B Hodson.', '71,044'],
#    ['WRITE-IN.', '1,033'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,745']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 31': [['Cheryl Albrecht',
#     '71,608'],
#    ['WRITE-IN.', '919'],
#    ['Over Votes', '3'],
#    ['Under Votes', '88,296']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 32': [['Merri Souther Wyatt',
#     '71,357'],
#    ['WRITE-IN.', '1,033'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,432']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 35': [['Paula J Kurshner',
#     '71,359'],
#    ['WRITE-IN.', '1,009'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,454']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 37': [['Leslie Roberts.',
#     '70,710'],
#    ['WRITE-IN.', '1,129'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,983']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 4': [['Adrienne Nelson', '74,220'],
#    ['WRITE-IN.', '963'],
#    ['Over Votes', '4'],
#    ['Under Votes', '85,639']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 7': [['Jerome LaBarre.', '71,278'],
#    ['WRITE-IN.', '1,132'],
#    ['Over Votes', '3'],
#    ['Under Votes', '88,413']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 8': [['Eric J Bergstrom',
#     '71,663'],
#    ['WRITE-IN.', '992'],
#    ['Over Votes', '3'],
#    ['Under Votes', '88,168']],
#   'Judge of the Ct. of Appeals, Position 10': [['Rex Armstrong', '71,832'],
#    ['WRITE-IN.', '1,063'],
#    ['Over Votes', '4'],
#    ['Under Votes', '87,927']],
#   'Judge of the Ct. of Appeals, Position 5': [['Rick Haselton', '72,033'],
#    ['WRITE-IN.', '1,087'],
#    ['Over Votes', '3'],
#    ['Under Votes', '87,703']],
#   'Judge of the Ct. of Appeals, Position 6': [['Tim Volpert.', '47,471'],
#    ['Allan J Arlow', '16,471'],
#    ['James C Egan', '29,336'],
#    ['WRITE-IN.', '732'],
#    ['Over Votes', '41'],
#    ['Under Votes', '66,775']],
#   'Judge of the Ct. of Appeals, Position 8': [['Lynn R Nakamoto', '75,530'],
#    ['WRITE-IN.', '989'],
#    ['Over Votes', '3'],
#    ['Under Votes', '84,304']],
#   'Judge of the Ct. of Appeals, Position 9': [['Erika Hadlock', '74,409'],
#    ['WRITE-IN.', '974'],
#    ['Over Votes', '3'],
#    ['Under Votes', '85,440']],
#   'Judge of the Supreme Court, Position 2': [['Dave Brewer.', '77,067'],
#    ['WRITE-IN.', '1,085'],
#    ['Over Votes', '7'],
#    ['Under Votes', '82,667']],
#   'Judge of the Supreme Court, Position 3': [['Timothy J Sercombe', '33,254'],
#    ['Nena Cook', '38,004'],
#    ['Richard C Baldwin.', '30,277'],
#    ['WRITE-IN.', '661'],
#    ['Over Votes', '67'],
#    ['Under Votes', '58,563']],
#   'Judge of the Supreme Court, Position 6': [['Virginia L Linder.', '74,315'],
#    ['WRITE-IN.', '1,178'],
#    ['Over Votes', '10'],
#    ['Under Votes', '85,323']],
#   'Mayor CITY OF PORTLAND': [['Steve Sung', '1,202'],
#    ['Jefferson Smith', '44,394'],
#    ['Scott Fernandez', '1,366'],
#    ['Dave Campbell', '318'],
#    ['Robert James Carron', '87'],
#    ['Max Bauske', '137'],
#    ['Samuel Belisle.', '59'],
#    ['Max Brumm', '790'],
#    ['Loren Charles Brown', '210'],
#    ['Eileen Brady', '29,295'],
#    ['Shonda Colleen Kelley', '278'],
#    ['Josh Nuttall', '69'],
#    ['Blake Nieman-Davis', '55'],
#    ['Lew Humble', '91'],
#    ['Charlie Hales', '50,220'],
#    ['Michael P Langley.', '509'],
#    ['Cameron Whitten', '1,729'],
#    ['David (The Ack) Ackerman', '360'],
#    ['Tre Arrow', '914'],
#    ['Bill Dant', '376'],
#    ['Howie Rubin.', '178'],
#    ['Christopher Rich', '115'],
#    ['Scott Rose', '1,734'],
#    ['WRITE-IN.', '479'],
#    ['Over Votes', '109'],
#    ['Under Votes', '4,934']],
#   'Metro Councilor, 5th District': [['Sam Chase', '24,963'],
#    ['Terry Parker', '1,927'],
#    ['Brad Perkins', '3,911'],
#    ['Helen Ying', '9,161'],
#    ['Michael (micro) W Durrow', '1,751'],
#    ['WRITE-IN.', '229'],
#    ['Over Votes', '16'],
#    ['Under Votes', '16,266']],
#   'Metro Councilor, 6th District': [['Bob Stacey', '39,794'],
#    ['Jonathan P Levine.', '6,773'],
#    ['WRITE-IN.', '356'],
#    ['Over Votes', '3'],
#    ['Under Votes', '18,015']],
#   'Representative in Congress, 1st District': [['Suzanne Bonamici', '8,234'],
#    ['WRITE-IN.', '54'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,604'],
#    ['Lisa Michaels', '719'],
#    ['Delinda Morgan.', '832'],
#    ['WRITE-IN.', '29'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,110']],
#   'Representative in Congress, 3rd District': [['Earl Blumenauer', '78,434'],
#    ['WRITE-IN.', '849'],
#    ['Over Votes', '3'],
#    ['Under Votes', '13,110'],
#    ['Ronald Green', '11,036'],
#    ['Delia Lopez.', '5,861'],
#    ['WRITE-IN.', '360'],
#    ['Over Votes', '2'],
#    ['Under Votes', '8,362']],
#   'Representative in Congress, 5th District': [['Kurt Schrader', '808'],
#    ['WRITE-IN.', '12'],
#    ['Over Votes', '0'],
#    ['Under Votes', '230'],
#    ['Fred Thompson', '199'],
#    ['Karen Bowerman.', '152'],
#    ['WRITE-IN.', '3'],
#    ['Over Votes', '0'],
#    ['Under Votes', '145']],
#   'Secretary of State': [['Kate Brown', '83,490'],
#    ['Paul Damian Wells.', '4,770'],
#    ['WRITE-IN.', '271'],
#    ['Over Votes', '12'],
#    ['Under Votes', '14,692'],
#    ['Knute Buehler', '15,824'],
#    ['WRITE-IN.', '588'],
#    ['Over Votes', '1'],
#    ['Under Votes', '13,480']],
#   'State Representative, 27th District': [['Tobias Read.', '292'],
#    ['WRITE-IN.', '1'],
#    ['Over Votes', '0'],
#    ['Under Votes', '96'],
#    ['Burton Keeble', '112'],
#    ['WRITE-IN.', '3'],
#    ['Over Votes', '0'],
#    ['Under Votes', '105']],
#   'State Representative, 31st District': [['Brad Witt', '575'],
#    ['WRITE-IN.', '9'],
#    ['Over Votes', '0'],
#    ['Under Votes', '272'],
#    ['Lew Barnes', '208'],
#    ['WRITE-IN.', '3'],
#    ['Over Votes', '0'],
#    ['Under Votes', '202']],
#   'State Representative, 33rd District': [['Mitch Greenlick', '2,492'],
#    ['WRITE-IN.', '21'],
#    ['Over Votes', '0'],
#    ['Under Votes', '931'],
#    ['Stevan Kirkpatrick', '320'],
#    ['WRITE-IN.', '2'],
#    ['Over Votes', '0'],
#    ['Under Votes', '464']],
#   'State Representative, 35th District': [['Margaret Doherty', '1,083'],
#    ['WRITE-IN.', '6'],
#    ['Over Votes', '0'],
#    ['Under Votes', '557'],
#    ['John Goodhouse.', '284'],
#    ['WRITE-IN.', '5'],
#    ['Over Votes', '0'],
#    ['Under Votes', '289']],
#   'State Representative, 36th District': [['Sharon Meieran.', '4,509'],
#    ['Benjamin Jay Barber', '240'],
#    ['Jennifer Williamson', '5,418'],
#    ['WRITE-IN.', '31'],
#    ['Over Votes', '2'],
#    ['Under Votes', '1,749'],
#    ['Bruce Neal', '1,302'],
#    ['WRITE-IN.', '40'],
#    ['Over Votes', '1'],
#    ['Under Votes', '1,717']],
#   'State Representative, 38th District': [['Chris Garrett', '3,750'],
#    ['WRITE-IN.', '33'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,839'],
#    ['Tom Maginnis', '846'],
#    ['WRITE-IN.', '17'],
#    ['Over Votes', '0'],
#    ['Under Votes', '812']],
#   'State Representative, 41st District': [['Carolyn Tomei', '3,711'],
#    ['WRITE-IN.', '35'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,453'],
#    ['Sam Cantrell', '186'],
#    ['Timothy E McMenamin', '575'],
#    ['WRITE-IN.', '8'],
#    ['Over Votes', '0'],
#    ['Under Votes', '329']],
#   'State Representative, 42nd District': [['Jules Kopel Bailey', '8,797'],
#    ['WRITE-IN.', '69'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,740'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '65'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,337']],
#   'State Representative, 43rd District': [['Lew Frederick', '9,069'],
#    ['WRITE-IN.', '69'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,692'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '43'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,187']],
#   'State Representative, 44th District': [['Tina Kotek', '6,019'],
#    ['WRITE-IN.', '98'],
#    ['Over Votes', '0'],
#    ['Under Votes', '2,276'],
#    ['Daniel Ticknor.', '217'],
#    ['Michael Harrington', '569'],
#    ['WRITE-IN.', '30'],
#    ['Over Votes', '2'],
#    ['Under Votes', '799']],
#   'State Representative, 45th District': [['Michael Dembrow', '8,015'],
#    ['WRITE-IN.', '67'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,615'],
#    ['Anne Marie Gurney.', '1,291'],
#    ['WRITE-IN.', '37'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,483']],
#   'State Representative, 46th District': [['Alissa Keny-Guyer.', '6,494'],
#    ['WRITE-IN.', '41'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,425'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '74'],
#    ['Over Votes', '0'],
#    ['Under Votes', '2,168']],
#   'State Representative, 47th District': [['Thuy Tran', '1,907'],
#    ['Jessica Vega Pederson', '2,282'],
#    ['Andrew Haynes', '504'],
#    ['WRITE-IN.', '30'],
#    ['Over Votes', '1'],
#    ['Under Votes', '957'],
#    ['Maggie Nelson', '1,570'],
#    ['WRITE-IN.', '31'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,352']],
#   'State Representative, 48th District': [['Mike Schaufler.', '781'],
#    ['Jeff Reardon', '1,373'],
#    ['WRITE-IN.', '10'],
#    ['Over Votes', '1'],
#    ['Under Votes', '257'],
#    ['George (Sonny) Yellott', '429'],
#    ['WRITE-IN.', '22'],
#    ['Over Votes', '0'],
#    ['Under Votes', '498']],
#   'State Representative, 49th District': [['Chris Gorsek', '2,392'],
#    ['WRITE-IN.', '92'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,068'],
#    ['Matthew Wand', '1,843'],
#    ['WRITE-IN.', '21'],
#    ['Over Votes', '0'],
#    ['Under Votes', '724']],
#   'State Representative, 50th District': [['Greg Matthews', '2,955'],
#    ['WRITE-IN.', '37'],
#    ['Over Votes', '0'],
#    ['Under Votes', '847'],
#    ['Logan Boettcher', '1,408'],
#    ['WRITE-IN.', '62'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,347']],
#   'State Representative, 51st District': [['Shemia Fagan', '1,343'],
#    ['WRITE-IN.', '31'],
#    ['Over Votes', '0'],
#    ['Under Votes', '765'],
#    ['Patrick Sheehan', '882'],
#    ['WRITE-IN.', '10'],
#    ['Over Votes', '0'],
#    ['Under Votes', '501']],
#   'State Representative, 52nd District': [['Peter Nordbye', '471'],
#    ['Marv Hollingsworth', '348'],
#    ['WRITE-IN.', '6'],
#    ['Over Votes', '0'],
#    ['Under Votes', '186'],
#    ['Mark Johnson', '557'],
#    ['WRITE-IN.', '11'],
#    ['Over Votes', '0'],
#    ['Under Votes', '394']],
#   'State Senator, 14th District': [['Mark Hass', '295'],
#    ['WRITE-IN.', '1'],
#    ['Over Votes', '0'],
#    ['Under Votes', '93'],
#    ['Gary Coe.', '137'],
#    ['WRITE-IN.', '2'],
#    ['Over Votes', '0'],
#    ['Under Votes', '81']],
#   'State Senator, 17th District': [['Elizabeth Steiner Hayward', '2,104'],
#    ['WRITE-IN.', '14'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,326'],
#    ['John Verbeek', '349'],
#    ['WRITE-IN.', '4'],
#    ['Over Votes', '0'],
#    ['Under Votes', '433']],
#   'State Senator, 18th District': [['Ginny Burdick', '9,912'],
#    ['WRITE-IN.', '73'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,610'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '519'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,119']],
#   'State Senator, 21st District': [['Diane Rosenbaum', '12,495'],
#    ['WRITE-IN.', '67'],
#    ['Over Votes', '0'],
#    ['Under Votes', '5,243'],
#    ['Cliff Hutchison', '1,048'],
#    ['WRITE-IN.', '43'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,409']],
#   'State Senator, 22nd District': [['Chip Shields', '14,916'],
#    ['WRITE-IN.', '125'],
#    ['Over Votes', '0'],
#    ['Under Votes', '6,182'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '107'],
#    ['Over Votes', '0'],
#    ['Under Votes', '2,740']],
#   'State Senator, 23rd District': [['Jackie Dingfelder.', '14,831'],
#    ['WRITE-IN.', '90'],
#    ['Over Votes', '0'],
#    ['Under Votes', '6,736'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '158'],
#    ['Over Votes', '0'],
#    ['Under Votes', '4,895']],
#   'State Senator, 25th District': [['Laurie Monnes Anderson', '5,701'],
#    ['WRITE-IN.', '110'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,580'],
#    ['Scott Hansen', '3,451'],
#    ['WRITE-IN.', '56'],
#    ['Over Votes', '1'],
#    ['Under Votes', '1,897']],
#   'State Treasurer': [['Ted Wheeler.', '78,800'],
#    ['WRITE-IN.', '425'],
#    ['Over Votes', '0'],
#    ['Under Votes', '24,010'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '2,158'],
#    ['Over Votes', '0'],
#    ['Under Votes', '27,735']],
#   'United States President': [['Barack Obama', '92,845'],
#    ['WRITE-IN.', '2,871'],
#    ['Over Votes', '2'],
#    ['Under Votes', '7,620'],
#    ['Rick Santorum', '2,381'],
#    ['Ron Paul.', '4,191'],
#    ['Newt Gingrich', '1,254'],
#    ['Mitt Romney.', '18,123'],
#    ['WRITE-IN.', '794'],
#    ['Over Votes', '10'],
#    ['Under Votes', '2,057']]},
#  'Republican': {'26-125 MULTNOMAH COUNTY LIBRARY': [['Yes', '128,814'],
#    ['No.', '23,566'],
#    ['Over Votes', '22'],
#    ['Under Votes', '8,424']],
#   '26-126 CITY OF PORTLAND': [['Yes', '95,904'],
#    ['No.', '15,356'],
#    ['Over Votes', '36'],
#    ['Under Votes', '28,712']],
#   '26-127 CITY OF PORTLAND': [['Yes', '87,732'],
#    ['No.', '25,581'],
#    ['Over Votes', '32'],
#    ['Under Votes', '26,663']],
#   '26-128 CITY OF PORTLAND': [['Yes', '94,824'],
#    ['No.', '20,739'],
#    ['Over Votes', '23'],
#    ['Under Votes', '24,422']],
#   '26-129 CITY OF PORTLAND': [['Yes', '95,642'],
#    ['No.', '21,823'],
#    ['Over Votes', '30'],
#    ['Under Votes', '22,513']],
#   '26-130 CITY OF PORTLAND': [['Yes', '92,564'],
#    ['No.', '24,894'],
#    ['Over Votes', '23'],
#    ['Under Votes', '22,527']],
#   '26-131 CITY OF PORTLAND': [['Yes', '87,341'],
#    ['No.', '26,517'],
#    ['Over Votes', '36'],
#    ['Under Votes', '26,114']],
#   '26-132 CITY OF PORTLAND': [['Yes', '100,276'],
#    ['No.', '11,454'],
#    ['Over Votes', '18'],
#    ['Under Votes', '28,260']],
#   '26-133 CITY OF PORTLAND': [['Yes', '92,087'],
#    ['No.', '16,066'],
#    ['Over Votes', '28'],
#    ['Under Votes', '31,827']],
#   '26-134 CITY OF PORTLAND': [['Yes', '97,053'],
#    ['No.', '15,047'],
#    ['Over Votes', '19'],
#    ['Under Votes', '27,889']],
#   '26-135 DAVID DOUGLAS SCHOOL DISTRICT #40': [['Yes', '5,680'],
#    ['No.', '3,060'],
#    ['Over Votes', '3'],
#    ['Under Votes', '605']],
#   '26-136 CITY OF GRESHAM': [['Yes', '7,836'],
#    ['No.', '3,077'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,585']],
#   '26-137 CITY OF GRESHAM': [['Yes', '9,054'],
#    ['No.', '1,731'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,713']],
#   '26-138 CITY OF GRESHAM': [['Yes', '9,473'],
#    ['No.', '1,391'],
#    ['Over Votes', '3'],
#    ['Under Votes', '1,631']],
#   '26-139 CITY OF GRESHAM': [['Yes', '9,990'],
#    ['No.', '946'],
#    ['Over Votes', '2'],
#    ['Under Votes', '1,560']],
#   '26-140 CITY OF GRESHAM': [['Yes', '8,696'],
#    ['No.', '1,748'],
#    ['Over Votes', '1'],
#    ['Under Votes', '2,053']],
#   'Attorney General': [['Dwight Holton', '25,889'],
#    ['Ellen Rosenblum', '63,141'],
#    ['WRITE-IN.', '163'],
#    ['Over Votes', '13'],
#    ['Under Votes', '14,029'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '2,452'],
#    ['Over Votes', '0'],
#    ['Under Votes', '27,441']],
#   'Commissioner, Pos. 1 CITY OF PORTLAND': [['Amanda Fritz', '54,323'],
#    ['David G Gwyther', '2,725'],
#    ['Mary Nolan', '52,823'],
#    ['Bruce Altizer', '5,511'],
#    ['Teressa L Raiford.', '3,840'],
#    ['WRITE-IN.', '427'],
#    ['Over Votes', '38'],
#    ['Under Votes', '20,321']],
#   'Commissioner, Pos. 4 CITY OF PORTLAND': [['Scott McAlpine.', '8,851'],
#    ['Brian Sidney Parrott.', '2,341'],
#    ['Steve Novick', '85,536'],
#    ['Mark White', '4,255'],
#    ['Jeri Williams', '5,608'],
#    ['Leah Marie Dumas', '4,879'],
#    ['James Rowell', '1,180'],
#    ['WRITE-IN.', '501'],
#    ['Over Votes', '46'],
#    ['Under Votes', '26,811']],
#   'County Commissioner Dist #1': [['Wes Soderback', '5,449'],
#    ['Deborah Kafoury', '31,954'],
#    ['WRITE-IN.', '183'],
#    ['Over Votes', '18'],
#    ['Under Votes', '15,850']],
#   'County Commissioner Dist #3': [['Judy Shiprack', '18,284'],
#    ['Patty Burkett', '5,835'],
#    ['WRITE-IN.', '238'],
#    ['Over Votes', '9'],
#    ['Under Votes', '12,945']],
#   'County Commissioner Dist #4': [['Diane McKeel', '13,723'],
#    ['WRITE-IN.', '293'],
#    ['Over Votes', '2'],
#    ['Under Votes', '10,693']],
#   'District Attorney, Multnomah County': [['Rod Underhill', '79,555'],
#    ['WRITE-IN.', '1,195'],
#    ['Over Votes', '3'],
#    ['Under Votes', '80,073']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 12': [['Janice R Wilson',
#     '72,187'],
#    ['WRITE-IN.', '966'],
#    ['Over Votes', '4'],
#    ['Under Votes', '87,669']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 16': [['Susan M Svetkey',
#     '72,734'],
#    ['WRITE-IN.', '912'],
#    ['Over Votes', '4'],
#    ['Under Votes', '87,176']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 23': [['Edward Jones', '70,810'],
#    ['WRITE-IN.', '994'],
#    ['Over Votes', '4'],
#    ['Under Votes', '89,018']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 28': [['Judith Hudson Matarazzo.',
#     '71,389'],
#    ['WRITE-IN.', '939'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,494']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 29': [['Kathryn Villa-Smith',
#     '70,773'],
#    ['WRITE-IN.', '925'],
#    ['Over Votes', '3'],
#    ['Under Votes', '89,125']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 3': [['Jerry B Hodson.', '71,044'],
#    ['WRITE-IN.', '1,033'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,745']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 31': [['Cheryl Albrecht',
#     '71,608'],
#    ['WRITE-IN.', '919'],
#    ['Over Votes', '3'],
#    ['Under Votes', '88,296']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 32': [['Merri Souther Wyatt',
#     '71,357'],
#    ['WRITE-IN.', '1,033'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,432']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 35': [['Paula J Kurshner',
#     '71,359'],
#    ['WRITE-IN.', '1,009'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,454']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 37': [['Leslie Roberts.',
#     '70,710'],
#    ['WRITE-IN.', '1,129'],
#    ['Over Votes', '4'],
#    ['Under Votes', '88,983']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 4': [['Adrienne Nelson', '74,220'],
#    ['WRITE-IN.', '963'],
#    ['Over Votes', '4'],
#    ['Under Votes', '85,639']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 7': [['Jerome LaBarre.', '71,278'],
#    ['WRITE-IN.', '1,132'],
#    ['Over Votes', '3'],
#    ['Under Votes', '88,413']],
#   'Judge of the Circuit Ct., 4th Dst., Pos. 8': [['Eric J Bergstrom',
#     '71,663'],
#    ['WRITE-IN.', '992'],
#    ['Over Votes', '3'],
#    ['Under Votes', '88,168']],
#   'Judge of the Ct. of Appeals, Position 10': [['Rex Armstrong', '71,832'],
#    ['WRITE-IN.', '1,063'],
#    ['Over Votes', '4'],
#    ['Under Votes', '87,927']],
#   'Judge of the Ct. of Appeals, Position 5': [['Rick Haselton', '72,033'],
#    ['WRITE-IN.', '1,087'],
#    ['Over Votes', '3'],
#    ['Under Votes', '87,703']],
#   'Judge of the Ct. of Appeals, Position 6': [['Tim Volpert.', '47,471'],
#    ['Allan J Arlow', '16,471'],
#    ['James C Egan', '29,336'],
#    ['WRITE-IN.', '732'],
#    ['Over Votes', '41'],
#    ['Under Votes', '66,775']],
#   'Judge of the Ct. of Appeals, Position 8': [['Lynn R Nakamoto', '75,530'],
#    ['WRITE-IN.', '989'],
#    ['Over Votes', '3'],
#    ['Under Votes', '84,304']],
#   'Judge of the Ct. of Appeals, Position 9': [['Erika Hadlock', '74,409'],
#    ['WRITE-IN.', '974'],
#    ['Over Votes', '3'],
#    ['Under Votes', '85,440']],
#   'Judge of the Supreme Court, Position 2': [['Dave Brewer.', '77,067'],
#    ['WRITE-IN.', '1,085'],
#    ['Over Votes', '7'],
#    ['Under Votes', '82,667']],
#   'Judge of the Supreme Court, Position 3': [['Timothy J Sercombe', '33,254'],
#    ['Nena Cook', '38,004'],
#    ['Richard C Baldwin.', '30,277'],
#    ['WRITE-IN.', '661'],
#    ['Over Votes', '67'],
#    ['Under Votes', '58,563']],
#   'Judge of the Supreme Court, Position 6': [['Virginia L Linder.', '74,315'],
#    ['WRITE-IN.', '1,178'],
#    ['Over Votes', '10'],
#    ['Under Votes', '85,323']],
#   'Mayor CITY OF PORTLAND': [['Steve Sung', '1,202'],
#    ['Jefferson Smith', '44,394'],
#    ['Scott Fernandez', '1,366'],
#    ['Dave Campbell', '318'],
#    ['Robert James Carron', '87'],
#    ['Max Bauske', '137'],
#    ['Samuel Belisle.', '59'],
#    ['Max Brumm', '790'],
#    ['Loren Charles Brown', '210'],
#    ['Eileen Brady', '29,295'],
#    ['Shonda Colleen Kelley', '278'],
#    ['Josh Nuttall', '69'],
#    ['Blake Nieman-Davis', '55'],
#    ['Lew Humble', '91'],
#    ['Charlie Hales', '50,220'],
#    ['Michael P Langley.', '509'],
#    ['Cameron Whitten', '1,729'],
#    ['David (The Ack) Ackerman', '360'],
#    ['Tre Arrow', '914'],
#    ['Bill Dant', '376'],
#    ['Howie Rubin.', '178'],
#    ['Christopher Rich', '115'],
#    ['Scott Rose', '1,734'],
#    ['WRITE-IN.', '479'],
#    ['Over Votes', '109'],
#    ['Under Votes', '4,934']],
#   'Metro Councilor, 5th District': [['Sam Chase', '24,963'],
#    ['Terry Parker', '1,927'],
#    ['Brad Perkins', '3,911'],
#    ['Helen Ying', '9,161'],
#    ['Michael (micro) W Durrow', '1,751'],
#    ['WRITE-IN.', '229'],
#    ['Over Votes', '16'],
#    ['Under Votes', '16,266']],
#   'Metro Councilor, 6th District': [['Bob Stacey', '39,794'],
#    ['Jonathan P Levine.', '6,773'],
#    ['WRITE-IN.', '356'],
#    ['Over Votes', '3'],
#    ['Under Votes', '18,015']],
#   'Representative in Congress, 1st District': [['Suzanne Bonamici', '8,234'],
#    ['WRITE-IN.', '54'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,604'],
#    ['Lisa Michaels', '719'],
#    ['Delinda Morgan.', '832'],
#    ['WRITE-IN.', '29'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,110']],
#   'Representative in Congress, 3rd District': [['Earl Blumenauer', '78,434'],
#    ['WRITE-IN.', '849'],
#    ['Over Votes', '3'],
#    ['Under Votes', '13,110'],
#    ['Ronald Green', '11,036'],
#    ['Delia Lopez.', '5,861'],
#    ['WRITE-IN.', '360'],
#    ['Over Votes', '2'],
#    ['Under Votes', '8,362']],
#   'Representative in Congress, 5th District': [['Kurt Schrader', '808'],
#    ['WRITE-IN.', '12'],
#    ['Over Votes', '0'],
#    ['Under Votes', '230'],
#    ['Fred Thompson', '199'],
#    ['Karen Bowerman.', '152'],
#    ['WRITE-IN.', '3'],
#    ['Over Votes', '0'],
#    ['Under Votes', '145']],
#   'Secretary of State': [['Kate Brown', '83,490'],
#    ['Paul Damian Wells.', '4,770'],
#    ['WRITE-IN.', '271'],
#    ['Over Votes', '12'],
#    ['Under Votes', '14,692'],
#    ['Knute Buehler', '15,824'],
#    ['WRITE-IN.', '588'],
#    ['Over Votes', '1'],
#    ['Under Votes', '13,480']],
#   'State Representative, 27th District': [['Tobias Read.', '292'],
#    ['WRITE-IN.', '1'],
#    ['Over Votes', '0'],
#    ['Under Votes', '96'],
#    ['Burton Keeble', '112'],
#    ['WRITE-IN.', '3'],
#    ['Over Votes', '0'],
#    ['Under Votes', '105']],
#   'State Representative, 31st District': [['Brad Witt', '575'],
#    ['WRITE-IN.', '9'],
#    ['Over Votes', '0'],
#    ['Under Votes', '272'],
#    ['Lew Barnes', '208'],
#    ['WRITE-IN.', '3'],
#    ['Over Votes', '0'],
#    ['Under Votes', '202']],
#   'State Representative, 33rd District': [['Mitch Greenlick', '2,492'],
#    ['WRITE-IN.', '21'],
#    ['Over Votes', '0'],
#    ['Under Votes', '931'],
#    ['Stevan Kirkpatrick', '320'],
#    ['WRITE-IN.', '2'],
#    ['Over Votes', '0'],
#    ['Under Votes', '464']],
#   'State Representative, 35th District': [['Margaret Doherty', '1,083'],
#    ['WRITE-IN.', '6'],
#    ['Over Votes', '0'],
#    ['Under Votes', '557'],
#    ['John Goodhouse.', '284'],
#    ['WRITE-IN.', '5'],
#    ['Over Votes', '0'],
#    ['Under Votes', '289']],
#   'State Representative, 36th District': [['Sharon Meieran.', '4,509'],
#    ['Benjamin Jay Barber', '240'],
#    ['Jennifer Williamson', '5,418'],
#    ['WRITE-IN.', '31'],
#    ['Over Votes', '2'],
#    ['Under Votes', '1,749'],
#    ['Bruce Neal', '1,302'],
#    ['WRITE-IN.', '40'],
#    ['Over Votes', '1'],
#    ['Under Votes', '1,717']],
#   'State Representative, 38th District': [['Chris Garrett', '3,750'],
#    ['WRITE-IN.', '33'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,839'],
#    ['Tom Maginnis', '846'],
#    ['WRITE-IN.', '17'],
#    ['Over Votes', '0'],
#    ['Under Votes', '812']],
#   'State Representative, 41st District': [['Carolyn Tomei', '3,711'],
#    ['WRITE-IN.', '35'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,453'],
#    ['Sam Cantrell', '186'],
#    ['Timothy E McMenamin', '575'],
#    ['WRITE-IN.', '8'],
#    ['Over Votes', '0'],
#    ['Under Votes', '329']],
#   'State Representative, 42nd District': [['Jules Kopel Bailey', '8,797'],
#    ['WRITE-IN.', '69'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,740'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '65'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,337']],
#   'State Representative, 43rd District': [['Lew Frederick', '9,069'],
#    ['WRITE-IN.', '69'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,692'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '43'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,187']],
#   'State Representative, 44th District': [['Tina Kotek', '6,019'],
#    ['WRITE-IN.', '98'],
#    ['Over Votes', '0'],
#    ['Under Votes', '2,276'],
#    ['Daniel Ticknor.', '217'],
#    ['Michael Harrington', '569'],
#    ['WRITE-IN.', '30'],
#    ['Over Votes', '2'],
#    ['Under Votes', '799']],
#   'State Representative, 45th District': [['Michael Dembrow', '8,015'],
#    ['WRITE-IN.', '67'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,615'],
#    ['Anne Marie Gurney.', '1,291'],
#    ['WRITE-IN.', '37'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,483']],
#   'State Representative, 46th District': [['Alissa Keny-Guyer.', '6,494'],
#    ['WRITE-IN.', '41'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,425'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '74'],
#    ['Over Votes', '0'],
#    ['Under Votes', '2,168']],
#   'State Representative, 47th District': [['Thuy Tran', '1,907'],
#    ['Jessica Vega Pederson', '2,282'],
#    ['Andrew Haynes', '504'],
#    ['WRITE-IN.', '30'],
#    ['Over Votes', '1'],
#    ['Under Votes', '957'],
#    ['Maggie Nelson', '1,570'],
#    ['WRITE-IN.', '31'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,352']],
#   'State Representative, 48th District': [['Mike Schaufler.', '781'],
#    ['Jeff Reardon', '1,373'],
#    ['WRITE-IN.', '10'],
#    ['Over Votes', '1'],
#    ['Under Votes', '257'],
#    ['George (Sonny) Yellott', '429'],
#    ['WRITE-IN.', '22'],
#    ['Over Votes', '0'],
#    ['Under Votes', '498']],
#   'State Representative, 49th District': [['Chris Gorsek', '2,392'],
#    ['WRITE-IN.', '92'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,068'],
#    ['Matthew Wand', '1,843'],
#    ['WRITE-IN.', '21'],
#    ['Over Votes', '0'],
#    ['Under Votes', '724']],
#   'State Representative, 50th District': [['Greg Matthews', '2,955'],
#    ['WRITE-IN.', '37'],
#    ['Over Votes', '0'],
#    ['Under Votes', '847'],
#    ['Logan Boettcher', '1,408'],
#    ['WRITE-IN.', '62'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,347']],
#   'State Representative, 51st District': [['Shemia Fagan', '1,343'],
#    ['WRITE-IN.', '31'],
#    ['Over Votes', '0'],
#    ['Under Votes', '765'],
#    ['Patrick Sheehan', '882'],
#    ['WRITE-IN.', '10'],
#    ['Over Votes', '0'],
#    ['Under Votes', '501']],
#   'State Representative, 52nd District': [['Peter Nordbye', '471'],
#    ['Marv Hollingsworth', '348'],
#    ['WRITE-IN.', '6'],
#    ['Over Votes', '0'],
#    ['Under Votes', '186'],
#    ['Mark Johnson', '557'],
#    ['WRITE-IN.', '11'],
#    ['Over Votes', '0'],
#    ['Under Votes', '394']],
#   'State Senator, 14th District': [['Mark Hass', '295'],
#    ['WRITE-IN.', '1'],
#    ['Over Votes', '0'],
#    ['Under Votes', '93'],
#    ['Gary Coe.', '137'],
#    ['WRITE-IN.', '2'],
#    ['Over Votes', '0'],
#    ['Under Votes', '81']],
#   'State Senator, 17th District': [['Elizabeth Steiner Hayward', '2,104'],
#    ['WRITE-IN.', '14'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,326'],
#    ['John Verbeek', '349'],
#    ['WRITE-IN.', '4'],
#    ['Over Votes', '0'],
#    ['Under Votes', '433']],
#   'State Senator, 18th District': [['Ginny Burdick', '9,912'],
#    ['WRITE-IN.', '73'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,610'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '519'],
#    ['Over Votes', '0'],
#    ['Under Votes', '3,119']],
#   'State Senator, 21st District': [['Diane Rosenbaum', '12,495'],
#    ['WRITE-IN.', '67'],
#    ['Over Votes', '0'],
#    ['Under Votes', '5,243'],
#    ['Cliff Hutchison', '1,048'],
#    ['WRITE-IN.', '43'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,409']],
#   'State Senator, 22nd District': [['Chip Shields', '14,916'],
#    ['WRITE-IN.', '125'],
#    ['Over Votes', '0'],
#    ['Under Votes', '6,182'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '107'],
#    ['Over Votes', '0'],
#    ['Under Votes', '2,740']],
#   'State Senator, 23rd District': [['Jackie Dingfelder.', '14,831'],
#    ['WRITE-IN.', '90'],
#    ['Over Votes', '0'],
#    ['Under Votes', '6,736'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '158'],
#    ['Over Votes', '0'],
#    ['Under Votes', '4,895']],
#   'State Senator, 25th District': [['Laurie Monnes Anderson', '5,701'],
#    ['WRITE-IN.', '110'],
#    ['Over Votes', '0'],
#    ['Under Votes', '1,580'],
#    ['Scott Hansen', '3,451'],
#    ['WRITE-IN.', '56'],
#    ['Over Votes', '1'],
#    ['Under Votes', '1,897']],
#   'State Treasurer': [['Ted Wheeler.', '78,800'],
#    ['WRITE-IN.', '425'],
#    ['Over Votes', '0'],
#    ['Under Votes', '24,010'],
#    ['NO CANDIDATE FILED', '0'],
#    ['WRITE-IN.', '2,158'],
#    ['Over Votes', '0'],
#    ['Under Votes', '27,735']],
#   'United States President': [['Barack Obama', '92,845'],
#    ['WRITE-IN.', '2,871'],
#    ['Over Votes', '2'],
#    ['Under Votes', '7,620'],
#    ['Rick Santorum', '2,381'],
#    ['Ron Paul.', '4,191'],
#    ['Newt Gingrich', '1,254'],
#    ['Mitt Romney.', '18,123'],
#    ['WRITE-IN.', '794'],
#    ['Over Votes', '10'],
#    ['Under Votes', '2,057']]}}

# %%
def display_primary_tables(key='P2012'):
    for party,data in all_tables[key].items():
        print(party.upper())
        print()
        for title,d in data.items():
            print(title)
            display(DF(d, columns=['name','votes']))
        print(20*'-')
        print()
        
def display_tables(key='2010'):
    for title,data in all_tables[key].items():
        print(title)
        display(DF(data, columns=['name','votes']))

# %%
display_tables()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4cf1261da286> in <module>()
# ----> 1 display_tables()
#
# <ipython-input-7-30babb327f2c> in display_tables(key)
#      10
#      11 def display_tables(key='2010'):
# ---> 12     for title,data in all_tables[key].items():
#      13         print(title)
#      14         display(DF(data, columns=['name','votes']))
#
# KeyError: '2010'
