# %%
import re

import pandas as pd
from pandas import DataFrame as DF, Series

import numpy as np

import requests
from bs4 import BeautifulSoup

from pprint import pprint

# %%
baseurl = 'http://results.oregonvotes.gov'
u = '/ResultsSW.aspx?type=CTYALL&cty=26&map=CTY&eid=82'
url = baseurl + u

# %%
def extract_rows(div):
    rows = div.findAll('div', {'class': 'section group'})
    rows = [d for d in rows if not d.parent.attrs]
    rows = [
        d for d in rows if 
        d.parent.parent.attrs['class'] == ['wrapper-inside', 'wrapper-border']
    ]
    return rows

def extract_title(div):
    return div.find('h1').contents[0]

def toint(s):
    return int(''.join(s.split(',')))

def extract_table_data(rows):
    data = []
    for i,r in enumerate(rows):
        row = []
        if i == len(rows) - 1:
            row.append('total')
            row.append(toint(r.findAll('div')[-1].contents[0]))
        else:
            row.append(r.find('h1').contents[0].strip())
            row.append(toint(r.findAll('div')[-1].contents[0]))
        data.append(row)
    return data

def extract_all_data(divs):
    all_data = {}
    for i,div in enumerate(divs):
        title = extract_title(div)
        rows = extract_rows(div)
        try:
            data = extract_table_data(rows)
            all_data[title] = data
        except Exception as e:
            print(i)
            print(title)
            print(e)
    return all_data

def get_html(url):
    r = requests.get(url.replace('\n', ''))
    return r.content.decode('utf-8')

def extract_divs(html):
    soup = BeautifulSoup(html, 'html.parser')
    return soup.findAll('div', {'class': ['wrapper-inside wrapper-border']})

def scrape_fancypage(url):
    html = get_html(url)
    divs = extract_divs(html)
    return extract_all_data(divs)

# %% [markdown]
# ## Scrape All Fancy Pages

# %%
baseurl = 'http://results.oregonvotes.gov/ResultsSW.aspx?type=CTYALL&cty=26&map=CTY'
urls = {
    '': 'P2018',
    '&eid=4': 'S2017',  # special election
    '&eid=82': 'G2016',
}

# %%
all_fancypage_data = {}
for u,v in urls.items():
    url = baseurl + u
    key = v
    all_data = scrape_fancypage(url)
    all_fancypage_data[key] = all_data
# Out:
# 88
# Burlington Water Commissioner, Pos 3
# 'NoneType' object is not callable
# 89
# Burlington Water Commissioner, Pos 5
# 'NoneType' object is not callable
# 98
# Pleasant Home Water Comm, Pos 1
# 'NoneType' object is not callable
# 39
# City of Wood Village Council, Pos 3
# 'NoneType' object is not callable
# 44
# West Soil & Water, Director, At Large 1
# 'NoneType' object is not callable
# 51
# Interlachen Water PUD Dir, Sub-Dist 5
# 'NoneType' object is not callable

# %%
list(all_fancypage_data['P2018'])
# Out:
# ['City of Portland Auditor',
#  'Multnomah Co Commissioner Dist #2',
#  'Multnomah County Sheriff',
#  'City of Portland Commissioner, Pos 3',
#  '34-284 Beaverton School District #48JT Levy Renewal to Protect Beaverton Schools Teachers and Class Sizes',
#  "26-197 CITY OF PORTLAND Renew Portland Children's Levy for five years.",
#  'Metro Councilor, District 1',
#  'Metro Councilor, District 2',
#  'City of Portland Commissioner, Pos 2',
#  'Multnomah County Auditor',
#  'Metro Council President',
#  'Metro Auditor',
#  'Multnomah County Comm Chair']

# %%
all_fancypage_data['P2018']['Metro Auditor']
# Out:
# [['Brian Evans', 80933], ['Write-in', 969], ['total', 81902]]

# %% [markdown]
# ## Scrape Odd 2016 Primary Page

# %%
url = 'https://multco.us/elections/may-2016-primary-election-results'
html = get_html(url)

# %%
def extract_oddpage_divs_titles(html):
    soup = BeautifulSoup(html, 'html.parser')
    divs = soup.findAll('div', {'class': ['views-row']})
    titles = [h.contents[0] for h in soup.findAll('h3')][2:]
    divs = [d for d in divs if d.parent.attrs['class'] == ['view-content']][1:]
    return divs, titles

def extract_rows(divs, titles):
    table_rows = {}
    first = True
    rows = []
    tix = 0
    for d in divs:
        if 'views-row-1' in d.attrs['class']:
            if not first:
                table_rows[titles[tix]] = rows
                tix += 1
            else:
                first = False
            rows = []
        rows.append(d)
    return table_rows

def extract_table_data(trows):
    data = []
    for i,r in enumerate(trows):
        divs = r.findAll('div')
        if i < len(trows) - 1:
            contents = [d.contents for d in divs[1:3]]
            name = contents[0][-1]
            votes = toint(contents[1][-1])
            data.append([name, votes])
        else:
            contents = [d.contents for d in divs[-2:]]
            a = contents[0][0].contents[0]
            a = re.sub(r':\s*', '', a)
            u = toint(contents[0][1])

            b = contents[1][0].contents[0]
            b = re.sub(r':\s*', '', b)
            v = toint(contents[1][1])
            data.append([a, u])
            data.append([b, v])
    return data

def scrape_oddpage(url):
    html = get_html(url)
    divs, titles = extract_oddpage_divs_titles(html)
    table_rows = extract_rows(divs, titles)
    all_data = {}
    for title, trows in table_rows.items():
        all_data[title] = extract_table_data(trows)
    return all_data

# %%
all_odd_data = scrape_oddpage(url)

# %%
all_odd_data
# Out:
# {'Attorney General (DEM)': [['Ellen Rosenblum', 118380],
#   ['Write-in', 1649],
#   ['Under Votes', 69944],
#   ['Over Votes', 0]],
#  'Attorney General (IND)': [['No candidate filed', 0],
#   ['Write-in', 1070],
#   ['Under Votes', 5844],
#   ['Over Votes', 0]],
#  'Attorney General (REP)': [['Daniel Zene Crowe', 17229],
#   ['Write-in', 394],
#   ['Under Votes', 19109],
#   ['Over Votes', 0]],
#  'City of Portland Commissioner, Pos 1': [['Lanita Duke', 16248],
#   ['Amanda Fritz', 120225],
#   ['Ann Sanderson', 18167],
#   ['Tabitha Ivan', 5789],
#   ['Sara Long', 4395],
#   ['David Morrison', 7117],
#   ['Write-in', 1396],
#   ['Under Votes', 47262],
#   ['Over Votes', 102]],
#  'City of Portland Commissioner, Pos 4': [['Michael W Durrow', 8514],
#   ['Leah Marie Dumas', 4048],
#   ['Steve Novick', 72140],
#   ['Suzanne Stahl', 11194],
#   ['Fred Stewart', 13848],
#   ['Joseph Puckett', 2047],
#   ['James Bernard Lee', 4194],
#   ['Chloe Eudaly', 25474],
#   ['Shannon Estabrook', 2487],
#   ['Stuart Emmons', 23735],
#   ['Write-in', 1308],
#   ['Under Votes', 51577],
#   ['Over Votes', 212]],
#  'City of Portland Mayor': [['Bruce Broussard', 7465],
#   ['Patty Burkett', 2346],
#   ['Jules Bailey', 31955],
#   ['Ted Wheeler', 105562],
#   ['Eric Alexander Calhoun', 358],
#   ['Bim Ditson', 2467],
#   ['Sean Davis', 5217],
#   ['David Schor', 5083],
#   ['Jessie Sponberg', 3235],
#   ['Sarah Iannarone', 22831],
#   ['David (The Ack) Ackerman', 2255],
#   ['Lew Humble', 748],
#   ['Deborah Harris', 1636],
#   ['Trevor Manning', 480],
#   ['Steven J Entwisle Sr', 405],
#   ['Write-in', 1040],
#   ['Under Votes', 27508],
#   ['Over Votes', 134]],
#  'District Attorney, Multnomah County': [['Rod Underhill', 130326],
#   ['Write-in', 2420],
#   ['Under Votes', 125894],
#   ['Over Votes', 8]],
#  'Governor (DEM)': [['Kate Brown', 150117],
#   ['Julian Bell', 12663],
#   ['Chet Chance', 1012],
#   ['Kevin M Forsythe', 1499],
#   ['Dave Stauffer', 2922],
#   ['Steve Johnson', 2150],
#   ['Write-in', 1235],
#   ['Under Votes', 18321],
#   ['Over Votes', 115]],
#  'Governor (IND)': [['Patrick Barney', 878],
#   ['Cliff Thomason', 1257],
#   ['Write-in', 1577],
#   ['Under Votes', 3199],
#   ['Over Votes', 7]],
#  'Governor (REP)': [['Bruce Cuff', 2643],
#   ['Bob Niemeyer', 2740],
#   ['Bob Forthan', 350],
#   ['Bud Pierce', 14216],
#   ['Allen Alley', 11020],
#   ['Write-in', 386],
#   ['Under Votes', 5366],
#   ['Over Votes', 32]],
#  'Judge of the Circuit Court, 4th District, Position 15': [['Bronson D James',
#    123407],
#   ['Write-in', 1895],
#   ['Under Votes', 133339],
#   ['Over Votes', 6]],
#  'Judge of the Circuit Court, 4th District, Position 17': [['Kelly Skye',
#    122565],
#   ['Write-in', 1855],
#   ['Under Votes', 134220],
#   ['Over Votes', 8]],
#  'Judge of the Circuit Court, 4th District, Position 20': [['Eric J Bloch',
#    121804],
#   ['Write-in', 1911],
#   ['Under Votes', 134926],
#   ['Over Votes', 6]],
#  'Judge of the Circuit Court, 4th District, Position 22': [['Angel Lopez',
#    125645],
#   ['Write-in', 1775],
#   ['Under Votes', 131221],
#   ['Over Votes', 6]],
#  'Judge of the Circuit Court, 4th District, Position 25': [['Kathleen M Dailey',
#    122946],
#   ['Write-in', 1831],
#   ['Under Votes', 133864],
#   ['Over Votes', 6]],
#  'Judge of the Circuit Court, 4th District, Position 26': [['Karin J Immergut',
#    122703],
#   ['Write-in', 1911],
#   ['Under Votes', 134026],
#   ['Over Votes', 8]],
#  'Judge of the Circuit Court, 4th District, Position 9': [['David F Rees',
#    122280],
#   ['Write-in', 1969],
#   ['Under Votes', 134391],
#   ['Over Votes', 8]],
#  'Judge of the Court of Appeals, Position 2': [['Rebecca Duncan', 124491],
#   ['Write-in', 1933],
#   ['Under Votes', 132218],
#   ['Over Votes', 4]],
#  'Judge of the Court of Appeals, Position 3': [['Darleen Ortega', 127111],
#   ['Write-in', 1890],
#   ['Under Votes', 129640],
#   ['Over Votes', 6]],
#  'Judge of the Court of Appeals, Position 7': [['Meagan A Flynn', 125802],
#   ['Write-in', 1799],
#   ['Under Votes', 131039],
#   ['Over Votes', 8]],
#  'Judge of the Supreme Court, Position 4': [['Rives Kistler', 125240],
#   ['Write-in', 2297],
#   ['Under Votes', 131105],
#   ['Over Votes', 4]],
#  'Judge of the Supreme Court, Position 5': [['Jack L Landau', 124246],
#   ['Write-in', 2109],
#   ['Under Votes', 132287],
#   ['Over Votes', 4]],
#  'Measure 26-170 MHCC Bond Measure': [['Yes', 27824],
#   ['No', 30907],
#   ['Under Votes', 5043],
#   ['Over Votes', 18]],
#  'Measure 26-171 Corbett School Bond Measure': [['Yes', 873],
#   ['No', 998],
#   ['Under Votes', 48],
#   ['Over Votes', 0]],
#  'Measure 26-172 City of Troutdale Charter Question': [['Yes', 3078],
#   ['No', 563],
#   ['Under Votes', 376],
#   ['Over Votes', 0]],
#  'Measure 26-173 City of Portland Gas Tax': [['Yes', 107869],
#   ['No', 98922],
#   ['Under Votes', 13791],
#   ['Over Votes', 102]],
#  'Measure 26-174 Oregon Historical Society Levy': [['Yes', 170098],
#   ['No', 67851],
#   ['Under Votes', 20666],
#   ['Over Votes', 58]],
#  'Measure 26-175 Centennial School Bond Measure': [['Yes', 4236],
#   ['No', 4856],
#   ['Under Votes', 490],
#   ['Over Votes', 8]],
#  'Metro Councilor, 5th District': [['Colby Clipston', 13777],
#   ['Sam Chase', 45189],
#   ['Write-in', 841],
#   ['Under Votes', 33996],
#   ['Over Votes', 14]],
#  'Metro Councilor, 6th District': [['Bob Stacey', 50910],
#   ['Write-in', 1116],
#   ['Under Votes', 49822],
#   ['Over Votes', 4]],
#  'Multnomah Co Commissioner Dist #1': [['Eric Zimmerman', 13089],
#   ['Mel Rader', 6492],
#   ['Brian Wilson', 5119],
#   ['Marisha Childs', 5889],
#   ['Ken Stokes', 1492],
#   ['Wes Soderback', 1205],
#   ['Sharon Meieran', 24728],
#   ['Write-in', 372],
#   ['Under Votes', 23092],
#   ['Over Votes', 61]],
#  'Multnomah Co Commissioner Dist #3': [['Jessica Vega Pederson', 29986],
#   ['Write-in', 623],
#   ['Under Votes', 29269],
#   ['Over Votes', 0]],
#  'Multnomah Co Commissioner Dist #4': [['Stanley Dirks', 4047],
#   ['Amanda Schroeder', 11488],
#   ['Lori Stegmann', 13640],
#   ['Write-in', 376],
#   ['Under Votes', 13062],
#   ['Over Votes', 28]],
#  'President (DEM)': [['Hillary Clinton', 76106],
#   ['Bernie Sanders', 110680],
#   ['Write-in', 1385],
#   ['Under Votes', 2107],
#   ['Over Votes', 36]],
#  'President (IND)': [['No candidate filed', 0],
#   ['Write-in', 3319],
#   ['Under Votes', 3599],
#   ['Over Votes', 0]],
#  'President (REP)': [['Ted Cruz', 5575],
#   ['John R Kasich', 8115],
#   ['Donald J Trump', 19316],
#   ['Write-in', 1730],
#   ['Under Votes', 2023],
#   ['Over Votes', 19]],
#  'Question 26-477': [['Yes', 0],
#   ['No', 0],
#   ['Under Votes', 1],
#   ['Over Votes', 0]],
#  'Secretary of State (DEM)': [['Richard Devlin', 37587],
#   ['Brad Avakian', 62204],
#   ['Val Hoyle', 50649],
#   ['Write-in', 1021],
#   ['Under Votes', 38475],
#   ['Over Votes', 81]],
#  'Secretary of State (IND)': [['Paul Damian Wells', 2188],
#   ['Write-in', 1184],
#   ['Under Votes', 3540],
#   ['Over Votes', 4]],
#  'Secretary of State (REP)': [['Dennis Richardson', 23598],
#   ['Sid Leiken', 5287],
#   ['Write-in', 311],
#   ['Under Votes', 7532],
#   ['Over Votes', 10]],
#  'State Representative, 27th District (DEM)': [['Darin Campbell', 40],
#   ['Sheri Malstrom', 350],
#   ['Write-in', 3],
#   ['Under Votes', 233],
#   ['Over Votes', 0]],
#  'State Representative, 27th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 0],
#   ['Under Votes', 15],
#   ['Over Votes', 0]],
#  'State Representative, 27th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 9],
#   ['Under Votes', 288],
#   ['Over Votes', 0]],
#  'State Representative, 31st District (DEM)': [['Brad Witt', 849],
#   ['Write-in', 17],
#   ['Under Votes', 578],
#   ['Over Votes', 0]],
#  'State Representative, 31st District (IND)': [['No candidate filed', 0],
#   ['Write-in', 5],
#   ['Under Votes', 48],
#   ['Over Votes', 0]],
#  'State Representative, 31st District (REP)': [['No candidate filed', 0],
#   ['Write-in', 19],
#   ['Under Votes', 505],
#   ['Over Votes', 0]],
#  'State Representative, 33rd District (DEM)': [['Mitch Greenlick', 3846],
#   ['Write-in', 46],
#   ['Under Votes', 2147],
#   ['Over Votes', 0]],
#  'State Representative, 33rd District (IND)': [['No candidate filed', 0],
#   ['Write-in', 19],
#   ['Under Votes', 223],
#   ['Over Votes', 0]],
#  'State Representative, 33rd District (REP)': [['John Verbeek', 465],
#   ['Write-in', 9],
#   ['Under Votes', 517],
#   ['Over Votes', 0]],
#  'State Representative, 35th District (DEM)': [['Margaret Doherty', 1620],
#   ['Write-in', 19],
#   ['Under Votes', 990],
#   ['Over Votes', 0]],
#  'State Representative, 35th District (IND)': [['Jessica L Cousineau', 32],
#   ['Write-in', 8],
#   ['Under Votes', 71],
#   ['Over Votes', 0]],
#  'State Representative, 35th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 30],
#   ['Under Votes', 611],
#   ['Over Votes', 0]],
#  'State Representative, 36th District (DEM)': [['Jennifer Williamson', 12344],
#   ['Write-in', 112],
#   ['Under Votes', 7594],
#   ['Over Votes', 0]],
#  'State Representative, 36th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 88],
#   ['Under Votes', 723],
#   ['Over Votes', 0]],
#  'State Representative, 36th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 76],
#   ['Under Votes', 3258],
#   ['Over Votes', 0]],
#  'State Representative, 38th District (DEM)': [['Ann Lininger', 5654],
#   ['Write-in', 69],
#   ['Under Votes', 3786],
#   ['Over Votes', 0]],
#  'State Representative, 38th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 55],
#   ['Under Votes', 291],
#   ['Over Votes', 0]],
#  'State Representative, 38th District (REP)': [['Patrick De Klotz', 865],
#   ['Write-in', 21],
#   ['Under Votes', 1123],
#   ['Over Votes', 0]],
#  'State Representative, 41st District (DEM)': [['Karin Power', 4946],
#   ['Write-in', 48],
#   ['Under Votes', 3800],
#   ['Over Votes', 0]],
#  'State Representative, 41st District (IND)': [['No candidate filed', 0],
#   ['Write-in', 28],
#   ['Under Votes', 221],
#   ['Over Votes', 0]],
#  'State Representative, 41st District (REP)': [['Tim McMenamin', 630],
#   ['Write-in', 10],
#   ['Under Votes', 538],
#   ['Over Votes', 0]],
#  'State Representative, 42nd District (DEM)': [['Rob Nosse', 14772],
#   ['Write-in', 219],
#   ['Under Votes', 10601],
#   ['Over Votes', 0]],
#  'State Representative, 42nd District (IND)': [['James E Stubbs', 192],
#   ['Write-in', 70],
#   ['Under Votes', 349],
#   ['Over Votes', 0]],
#  'State Representative, 42nd District (REP)': [['No candidate filed', 0],
#   ['Write-in', 67],
#   ['Under Votes', 1409],
#   ['Over Votes', 0]],
#  'State Representative, 43rd District (DEM)': [['Tawna Sanchez', 9408],
#   ['Roberta Phillip-Robbins', 9240],
#   ['Robert E Andrews Jr', 406],
#   ['Write-in', 49],
#   ['Under Votes', 5347],
#   ['Over Votes', 16]],
#  'State Representative, 43rd District (IND)': [['No candidate filed', 0],
#   ['Write-in', 85],
#   ['Under Votes', 464],
#   ['Over Votes', 0]],
#  'State Representative, 43rd District (REP)': [['No candidate filed', 0],
#   ['Write-in', 44],
#   ['Under Votes', 1290],
#   ['Over Votes', 0]],
#  'State Representative, 44th District (DEM)': [['Sharon Nasset', 2834],
#   ['Tina Kotek', 10607],
#   ['Write-in', 73],
#   ['Under Votes', 3875],
#   ['Over Votes', 25]],
#  'State Representative, 44th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 98],
#   ['Under Votes', 475],
#   ['Over Votes', 0]],
#  'State Representative, 44th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 82],
#   ['Under Votes', 1753],
#   ['Over Votes', 0]],
#  'State Representative, 45th District (DEM)': [['Barbara Smith Warner', 11343],
#   ['Write-in', 140],
#   ['Under Votes', 8311],
#   ['Over Votes', 0]],
#  'State Representative, 45th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 73],
#   ['Under Votes', 565],
#   ['Over Votes', 0]],
#  'State Representative, 45th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 64],
#   ['Under Votes', 2970],
#   ['Over Votes', 0]],
#  'State Representative, 46th District (DEM)': [['Alissa Keny-Guyer', 10672],
#   ['Write-in', 156],
#   ['Under Votes', 7649],
#   ['Over Votes', 0]],
#  'State Representative, 46th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 66],
#   ['Under Votes', 507],
#   ['Over Votes', 0]],
#  'State Representative, 46th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 67],
#   ['Under Votes', 2465],
#   ['Over Votes', 0]],
#  'State Representative, 47th District (DEM)': [['Gloria Ngezaho', 1947],
#   ['Diego Hernandez', 4616],
#   ['Write-in', 78],
#   ['Under Votes', 2699],
#   ['Over Votes', 2]],
#  'State Representative, 47th District (IND)': [['Michael P Langley', 212],
#   ['Write-in', 30],
#   ['Under Votes', 269],
#   ['Over Votes', 0]],
#  'State Representative, 47th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 135],
#   ['Under Votes', 3409],
#   ['Over Votes', 0]],
#  'State Representative, 48th District (DEM)': [['Jeff Reardon', 2914],
#   ['Write-in', 67],
#   ['Under Votes', 1850],
#   ['Over Votes', 0]],
#  'State Representative, 48th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 36],
#   ['Under Votes', 180],
#   ['Over Votes', 0]],
#  'State Representative, 48th District (REP)': [['George (Sonny) Yellott', 597],
#   ['Write-in', 19],
#   ['Under Votes', 588],
#   ['Over Votes', 0]],
#  'State Representative, 49th District (DEM)': [['Chris Gorsek', 4606],
#   ['Write-in', 59],
#   ['Under Votes', 2595],
#   ['Over Votes', 0]],
#  'State Representative, 49th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 60],
#   ['Under Votes', 428],
#   ['Over Votes', 0]],
#  'State Representative, 49th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 150],
#   ['Under Votes', 4120],
#   ['Over Votes', 0]],
#  'State Representative, 50th District (DEM)': [['Carla Piluso', 5192],
#   ['Write-in', 123],
#   ['Under Votes', 2458],
#   ['Over Votes', 0]],
#  'State Representative, 50th District (IND)': [['Michael Calcagno', 248],
#   ['Write-in', 35],
#   ['Under Votes', 227],
#   ['Over Votes', 0]],
#  'State Representative, 50th District (REP)': [['Stella Armstrong', 2210],
#   ['Write-in', 416],
#   ['Under Votes', 2172],
#   ['Over Votes', 0]],
#  'State Representative, 51st District (DEM)': [['Janelle S Bynum', 1963],
#   ['Randy Shannon', 858],
#   ['Write-in', 38],
#   ['Under Votes', 1114],
#   ['Over Votes', 0]],
#  'State Representative, 51st District (IND)': [['No candidate filed', 0],
#   ['Write-in', 61],
#   ['Under Votes', 178],
#   ['Over Votes', 0]],
#  'State Representative, 51st District (REP)': [['Lori Chavez-DeRemer', 1020],
#   ['Write-in', 27],
#   ['Under Votes', 865],
#   ['Over Votes', 0]],
#  'State Representative, 52nd District (DEM)': [['Mark Reynolds', 961],
#   ['Walt Trandum', 251],
#   ['Write-in', 20],
#   ['Under Votes', 749],
#   ['Over Votes', 2]],
#  'State Representative, 52nd District (IND)': [['No candidate filed', 0],
#   ['Write-in', 34],
#   ['Under Votes', 145],
#   ['Over Votes', 0]],
#  'State Representative, 52nd District (REP)': [['Mark Johnson', 1071],
#   ['Write-in', 12],
#   ['Under Votes', 736],
#   ['Over Votes', 0]],
#  'State Senator, 14th District (DEM)': [['Mark Hass', 436],
#   ['Write-in', 2],
#   ['Under Votes', 188],
#   ['Over Votes', 0]],
#  'State Senator, 14th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 1],
#   ['Under Votes', 14],
#   ['Over Votes', 0]],
#  'State Senator, 14th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 11],
#   ['Under Votes', 286],
#   ['Over Votes', 0]],
#  'State Senator, 18th District (DEM)': [['Ginny Burdick', 14438],
#   ['Write-in', 145],
#   ['Under Votes', 8096],
#   ['Over Votes', 0]],
#  'State Senator, 18th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 119],
#   ['Under Votes', 803],
#   ['Over Votes', 0]],
#  'State Senator, 18th District (REP)': [['No candidate filed', 0],
#   ['Write-in', 88],
#   ['Under Votes', 3887],
#   ['Over Votes', 0]],
#  'State Senator, 21st District (DEM)': [['John Sweeney', 2213],
#   ['Kathleen Taylor', 21999],
#   ['Write-in', 138],
#   ['Under Votes', 10033],
#   ['Over Votes', 6]],
#  'State Senator, 21st District (IND)': [['No candidate filed', 0],
#   ['Write-in', 172],
#   ['Under Votes', 688],
#   ['Over Votes', 0]],
#  'State Senator, 21st District (REP)': [['No candidate filed', 0],
#   ['Write-in', 114],
#   ['Under Votes', 2540],
#   ['Over Votes', 0]],
#  'State Senator, 22nd District (DEM)': [['Lew Frederick', 25360],
#   ['Write-in', 279],
#   ['Under Votes', 16220],
#   ['Over Votes', 0]],
#  'State Senator, 22nd District (IND)': [['No candidate filed', 0],
#   ['Write-in', 171],
#   ['Under Votes', 951],
#   ['Over Votes', 0]],
#  'State Senator, 22nd District (REP)': [['No candidate filed', 0],
#   ['Write-in', 128],
#   ['Under Votes', 3041],
#   ['Over Votes', 0]],
#  'State Senator, 23rd District (DEM)': [['Michael Dembrow', 22137],
#   ['Write-in', 288],
#   ['Under Votes', 15846],
#   ['Over Votes', 0]],
#  'State Senator, 23rd District (IND)': [['No candidate filed', 0],
#   ['Write-in', 140],
#   ['Under Votes', 1071],
#   ['Over Votes', 0]],
#  'State Senator, 23rd District (REP)': [['No candidate filed', 0],
#   ['Write-in', 155],
#   ['Under Votes', 5411],
#   ['Over Votes', 0]],
#  'State Senator, 25th District (DEM)': [['Laurie Monnes Anderson', 10085],
#   ['Write-in', 162],
#   ['Under Votes', 4786],
#   ['Over Votes', 0]],
#  'State Senator, 25th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 202],
#   ['Under Votes', 796],
#   ['Over Votes', 0]],
#  'State Senator, 25th District (REP)': [['Tamie Tlustos-Arnold', 4932],
#   ['Write-in', 85],
#   ['Under Votes', 4050],
#   ['Over Votes', 2]],
#  'State Treasurer (DEM)': [['Tobias Read', 112172],
#   ['Write-in', 1878],
#   ['Under Votes', 75922],
#   ['Over Votes', 2]],
#  'State Treasurer (IND)': [['Chris Telfer', 2561],
#   ['Write-in', 666],
#   ['Under Votes', 3686],
#   ['Over Votes', 2]],
#  'State Treasurer (REP)': [['Jeff Gudman', 19708],
#   ['Write-in', 450],
#   ['Under Votes', 16574],
#   ['Over Votes', 0]],
#  'US Representative, 1st District (DEM)': [['Suzanne Bonamici', 13039],
#   ['Shabba Woodley', 974],
#   ['Write-in', 49],
#   ['Under Votes', 2350],
#   ['Over Votes', 0]],
#  'US Representative, 1st District (IND)': [['No candidate filed', 0],
#   ['Write-in', 103],
#   ['Under Votes', 522],
#   ['Over Votes', 0]],
#  'US Representative, 1st District (REP)': [['Jonathan E Burgess', 253],
#   ['Brian J Heinrich', 689],
#   ['Delinda Morgan', 334],
#   ['Write-in', 42],
#   ['Under Votes', 1765],
#   ['Over Votes', 0]],
#  'US Representative, 3rd District (DEM)': [['Earl Blumenauer', 134220],
#   ['Write-in', 2304],
#   ['Under Votes', 35512],
#   ['Over Votes', 8]],
#  'US Representative, 3rd District (IND)': [['David W Walker', 2080],
#   ['Write-in', 755],
#   ['Under Votes', 3380],
#   ['Over Votes', 2]],
#  'US Representative, 3rd District (REP)': [['No candidate filed', 0],
#   ['Write-in', 1551],
#   ['Under Votes', 31506],
#   ['Over Votes', 0]],
#  'US Representative, 5th District (DEM)': [['Kurt Schrader', 1155],
#   ['Dave McTeague', 431],
#   ['Write-in', 5],
#   ['Under Votes', 251],
#   ['Over Votes', 2]],
#  'US Representative, 5th District (IND)': [['No candidate filed', 0],
#   ['Write-in', 22],
#   ['Under Votes', 55],
#   ['Over Votes', 0]],
#  'US Representative, 5th District (REP)': [['Earl D Rainey', 23],
#   ['Colm Willis', 275],
#   ['Ben West', 103],
#   ['Seth Allan', 60],
#   ['Write-in', 4],
#   ['Under Votes', 162],
#   ['Over Votes', 0]],
#  'US Senator (DEM)': [['Ron Wyden', 148978],
#   ['Paul B Weaver', 3555],
#   ['Kevin H Stine', 21510],
#   ['Write-in', 603],
#   ['Under Votes', 15628],
#   ['Over Votes', 46]],
#  'US Senator (IND)': [['Steven C Reynolds', 1353],
#   ['Marvin Sandnes', 672],
#   ['Write-in', 1464],
#   ['Under Votes', 3428],
#   ['Over Votes', 3]],
#  'US Senator (REP)': [['Sam Carpenter', 9203],
#   ['Mark Callahan', 9937],
#   ['Faye Stewart', 4242],
#   ['Dan Laschober', 3207],
#   ['Write-in', 477],
#   ['Under Votes', 9697],
#   ['Over Votes', 13]]}
